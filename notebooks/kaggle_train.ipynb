# %% [markdown]
# # Mini-VLA CL week-4 runner
#
# Enable Internet. Install packages with **CPU** first, then switch accelerator to **GPU T4** for training.
# Do not leave GPU idle. Download `results/` before the session ends.
# Code should live in this repo (Dataset or `git clone`); this notebook only calls the package.

# %%
# !pip install gymnasium minigrid transformers matplotlib

# %%
import os
os.environ.setdefault("PYTHONPATH", "/kaggle/working/mini_vla_cl")

# %%
# !python -m mini_vla_cl collect --skill goto --encoder clip --device cuda
# !python -m mini_vla_cl collect --skill pickup --encoder clip --device cuda
# !python -m mini_vla_cl train --method naive --skills goto,pickup --encoder clip --device cuda
# !python -m mini_vla_cl train --method replay --skills goto,pickup --encoder clip --device cuda
# !python -m mini_vla_cl plot --naive results/naive.json --replay results/replay.json --out results/week4.png
